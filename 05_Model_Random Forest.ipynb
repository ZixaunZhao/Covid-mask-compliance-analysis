# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from IPython.display import display, Markdown
from imblearn.over_sampling import RandomOverSampler
from imblearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedKFold, RandomizedSearchCV
from sklearn.metrics import (
    precision_score,
    recall_score,
    roc_auc_score,
    accuracy_score,
    f1_score,
    confusion_matrix,
    roc_curve,
)

DATA_DIR = Path("../data/paper_final_splits")

RANDOM_STATE = 20240627
N_SPLITS = 5
N_ITER_SEARCH = 40
TOP_N_FEATURES = 15

TASKS = {
    "before_mask": "Before mandate - Face mask",
    "after_mask": "After mandate - Face mask",
    "before_protective": "Before mandate - Protective behaviour",
    "after_protective": "After mandate - Protective behaviour",
}

METRICS = ["precision", "recall", "roc_auc", "accuracy", "f1"]


def load_task(task):
    X_train = pd.read_csv(DATA_DIR / f"X_train_{task}.csv")
    X_test = pd.read_csv(DATA_DIR / f"X_test_{task}.csv")
    y_train = pd.read_csv(DATA_DIR / f"y_train_{task}.csv").iloc[:, 0].astype(int)
    y_test = pd.read_csv(DATA_DIR / f"y_test_{task}.csv").iloc[:, 0].astype(int)
    return X_train, X_test, y_train, y_test


def get_metrics(y_true, y_pred, y_prob):
    return {
        "precision": precision_score(y_true, y_pred, zero_division=0),
        "recall": recall_score(y_true, y_pred, zero_division=0),
        "roc_auc": roc_auc_score(y_true, y_prob),
        "accuracy": accuracy_score(y_true, y_pred),
        "f1": f1_score(y_true, y_pred, zero_division=0),
    }


def build_search():
    pipe = Pipeline(steps=[
        ("ros", RandomOverSampler(random_state=RANDOM_STATE)),
        ("model", RandomForestClassifier(
            n_estimators=250,
            random_state=RANDOM_STATE,
            n_jobs=-1
        ))
    ])

    param_distributions = {
        "model__max_depth": [5, 8, 10, 12, 15, 20, None],
        "model__min_samples_split": [2, 5, 10, 20, 30],
        "model__min_samples_leaf": [1, 2, 5, 10],
        "model__max_features": ["sqrt", "log2", 0.3, 0.5, 0.7, None],
        "model__bootstrap": [True],
    }

    cv = StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=RANDOM_STATE)

    search = RandomizedSearchCV(
        estimator=pipe,
        param_distributions=param_distributions,
        n_iter=N_ITER_SEARCH,
        scoring="roc_auc",
        cv=cv,
        random_state=RANDOM_STATE,
        n_jobs=1,
        refit=True,
        verbose=0,
        return_train_score=False,
    )
    return search


def plot_confusion_matrix(cm, title):
    fig, ax = plt.subplots(figsize=(4, 4))
    ax.imshow(cm)
    ax.set_title(title)
    ax.set_xlabel("Predicted label")
    ax.set_ylabel("True label")
    ax.set_xticks([0, 1])
    ax.set_yticks([0, 1])

    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, str(cm[i, j]), ha="center", va="center")

    plt.show()


def plot_roc_curve(y_true, y_prob, title):
    fpr, tpr, _ = roc_curve(y_true, y_prob)
    auc_value = roc_auc_score(y_true, y_prob)

    plt.figure(figsize=(5, 4))
    plt.plot(fpr, tpr, label=f"AUC = {auc_value:.4f}")
    plt.plot([0, 1], [0, 1], linestyle="--")
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title(title)
    plt.legend()
    plt.show()


def plot_top_importance(importance_df, title, top_n=15):
    top_df = importance_df.head(top_n).sort_values("importance", ascending=True)

    plt.figure(figsize=(8, max(5, top_n * 0.35)))
    plt.barh(top_df["feature"], top_df["importance"])
    plt.xlabel("Feature importance")
    plt.title(title)
    plt.show()


all_summary = []
results = {}

for task, label in TASKS.items():
    X_train, X_test, y_train, y_test = load_task(task)

    search = build_search()
    search.fit(X_train, y_train)

    best_model = search.best_estimator_
    best_params = search.best_params_
    best_cv_auc = search.best_score_

    cv_results_df = pd.DataFrame(search.cv_results_).sort_values("rank_test_score")
    display(Markdown(f"## {label}"))
    display(Markdown("### Best hyperparameters"))
    display(pd.DataFrame([best_params]))

    display(Markdown("### Top search results"))
    show_cols = [
        "rank_test_score",
        "mean_test_score",
        "std_test_score",
        "param_model__max_depth",
        "param_model__min_samples_split",
        "param_model__min_samples_leaf",
        "param_model__max_features",
        "param_model__bootstrap",
    ]
    display(cv_results_df[show_cols].head(10).round(6))

    y_test_pred = best_model.predict(X_test)
    y_test_prob = best_model.predict_proba(X_test)[:, 1]

    test_metrics = get_metrics(y_test, y_test_pred, y_test_prob)
    test_df = pd.DataFrame([{
        "model": "random_forest",
        "task": task,
        "label": label,
        "best_cv_auc": best_cv_auc,
        **test_metrics
    }])

    display(Markdown("### Test metrics"))
    display(test_df.round(4))

    fitted_model = best_model.named_steps["model"]
    importance_df = pd.DataFrame({
        "feature": X_train.columns,
        "importance": fitted_model.feature_importances_
    }).sort_values("importance", ascending=False)

    display(Markdown("### Top feature importance"))
    display(importance_df.head(TOP_N_FEATURES).round(6))

    plot_top_importance(
        importance_df,
        title=f"Random Forest - Top feature importance - {label}",
        top_n=TOP_N_FEATURES
    )

    plot_confusion_matrix(
        confusion_matrix(y_test, y_test_pred),
        title=f"Random Forest - Confusion matrix - {label}"
    )

    plot_roc_curve(
        y_test,
        y_test_prob,
        title=f"Random Forest - ROC curve - {label}"
    )

    results[task] = {
        "best_params": best_params,
        "best_cv_auc": best_cv_auc,
        "test_df": test_df,
        "importance_df": importance_df,
    }

    all_summary.append({
        "model": "random_forest",
        "task": task,
        "label": label,
        "best_cv_auc": best_cv_auc,
        **test_metrics
    })

display(Markdown("## Overall summary"))
display(pd.DataFrame(all_summary).round(4))
# Out:
# ## Before mandate - Face mask
# ### Best hyperparameters
#    model__min_samples_split  model__min_samples_leaf  model__max_features  \
# 0                        10                        2                  0.3
#
#   model__max_depth  model__bootstrap
# 0             None              True
# ### Top search results
#     rank_test_score  mean_test_score  std_test_score param_model__max_depth  \
# 14                1         0.854209        0.008063                   None
# 23                2         0.853145        0.007629                     20
# 33                3         0.852592        0.007970                     12
# 22                4         0.852314        0.007064                     20
# 20                5         0.851964        0.007733                     20
# 37                6         0.851526        0.009369                     12
# 35                7         0.851221        0.008294                     12
# 31                8         0.850880        0.008564                     12
# 5                 9         0.850685        0.008723                   None
# 9                10         0.850579        0.008289                     20
#
#     param_model__min_samples_split  param_model__min_samples_leaf  \
# 14                              10                              2
# 23                               5                              2
# 33                               5                              2
# 22                              10                              2
# 20                               5                              1
# 37                              10                              1
# 35                              20                              1
# 31                              10                              5
# 5                               20                              5
# 9                               20                             10
#
#    param_model__max_features  param_model__bootstrap
# 14                       0.3                    True
# 23                      sqrt                    True
# 33                       0.3                    True
# 22                      log2                    True
# 20                      log2                    True
# 37                       0.3                    True
# 35                       0.3                    True
# 31                       0.5                    True
# 5                        0.5                    True
# 9                        0.5                    True
# ### Test metrics
#            model         task                       label  best_cv_auc  \
# 0  random_forest  before_mask  Before mandate - Face mask       0.8542
#
#    precision  recall  roc_auc  accuracy      f1
# 0     0.5968  0.6192   0.8407    0.7936  0.6078
# ### Top feature importance
#                                    feature  importance
# 6        protective_behaviour_nomask_scale    0.161531
# 1                                      age    0.101966
# 7                              week_number    0.099047
# 8                    state_New South Wales    0.093736
# 0                                i2_health    0.069650
# 4                                     r1_1    0.062968
# 3                           cantril_ladder    0.047444
# 5                                     r1_2    0.046468
# 2                           household_size    0.035619
# 57                    d1_comorbidities_Yes    0.013564
# 15                             gender_Male    0.012043
# 31              WCRex2_A lot of confidence    0.010494
# 26                 i11_health_Very willing    0.010303
# 17                           i9_health_Yes    0.010103
# 19  employment_status_Part time employment    0.009854
# ## After mandate - Face mask
# ### Best hyperparameters
#    model__min_samples_split  model__min_samples_leaf  model__max_features  \
# 0                        10                        2                  0.3
#
#   model__max_depth  model__bootstrap
# 0             None              True
# ### Top search results
#     rank_test_score  mean_test_score  std_test_score param_model__max_depth  \
# 14                1         0.889569        0.003712                   None
# 15                2         0.888904        0.003797                     12
# 5                 3         0.888428        0.002721                   None
# 31                4         0.888190        0.002961                     12
# 32                5         0.888062        0.002449                     15
# 33                6         0.887771        0.003646                     12
# 24                7         0.887754        0.002656                     20
# 9                 7         0.887754        0.002656                     20
# 37                9         0.887034        0.003708                     12
# 4                10         0.886625        0.001993                     15
#
#     param_model__min_samples_split  param_model__min_samples_leaf  \
# 14                              10                              2
# 15                               2                              2
# 5                               20                              5
# 31                              10                              5
# 32                               5                             10
# 33                               5                              2
# 24                               2                             10
# 9                               20                             10
# 37                              10                              1
# 4                               20                             10
#
#    param_model__max_features  param_model__bootstrap
# 14                       0.3                    True
# 15                       0.5                    True
# 5                        0.5                    True
# 31                       0.5                    True
# 32                       0.5                    True
# 33                       0.3                    True
# 24                       0.5                    True
# 9                        0.5                    True
# 37                       0.3                    True
# 4                        0.7                    True
# ### Test metrics
#            model        task                      label  best_cv_auc  \
# 0  random_forest  after_mask  After mandate - Face mask       0.8896
#
#    precision  recall  roc_auc  accuracy     f1
# 0      0.885  0.9053   0.8895      0.85  0.895
# ### Top feature importance
#                               feature  importance
# 7                         week_number    0.181450
# 6   protective_behaviour_nomask_scale    0.150604
# 1                                 age    0.067621
# 14            state_Western Australia    0.062408
# 10                   state_Queensland    0.058445
# 0                           i2_health    0.047616
# 5                                r1_2    0.037461
# 4                                r1_1    0.036900
# 3                      cantril_ladder    0.033884
# 13                     state_Victoria    0.033768
# 2                      household_size    0.027819
# 8               state_New South Wales    0.024616
# 26            i11_health_Very willing    0.019022
# 17                      i9_health_Yes    0.011983
# 11              state_South Australia    0.010035
# ## Before mandate - Protective behaviour
# ### Best hyperparameters
#    model__min_samples_split  model__min_samples_leaf model__max_features  \
# 0                         5                        1                log2
#
#    model__max_depth  model__bootstrap
# 0                20              True
# ### Top search results
#     rank_test_score  mean_test_score  std_test_score param_model__max_depth  \
# 20                1         0.779098        0.004703                     20
# 23                2         0.778717        0.007284                     20
# 22                3         0.778561        0.006263                     20
# 14                4         0.776493        0.007669                   None
# 33                5         0.776357        0.007751                     12
# 16                6         0.775976        0.006515                     12
# 37                7         0.775843        0.007632                     12
# 2                 8         0.775109        0.006786                     15
# 35                9         0.774967        0.008153                     12
# 15               10         0.774200        0.008848                     12
#
#     param_model__min_samples_split  param_model__min_samples_leaf  \
# 20                               5                              1
# 23                               5                              2
# 22                              10                              2
# 14                              10                              2
# 33                               5                              2
# 16                               5                              2
# 37                              10                              1
# 2                               30                              2
# 35                              20                              1
# 15                               2                              2
#
#    param_model__max_features  param_model__bootstrap
# 20                      log2                    True
# 23                      sqrt                    True
# 22                      log2                    True
# 14                       0.3                    True
# 33                       0.3                    True
# 16                      log2                    True
# 37                       0.3                    True
# 2                       log2                    True
# 35                       0.3                    True
# 15                       0.5                    True
# ### Test metrics
#            model               task                                  label  \
# 0  random_forest  before_protective  Before mandate - Protective behaviour
#
#    best_cv_auc  precision  recall  roc_auc  accuracy      f1
# 0       0.7791      0.726  0.7554   0.7963    0.7196  0.7404
# ### Top feature importance
#                                    feature  importance
# 0                                i2_health    0.137252
# 4                                     r1_1    0.095571
# 1                                      age    0.081791
# 6                              week_number    0.077675
# 3                           cantril_ladder    0.053424
# 5                                     r1_2    0.051917
# 2                           household_size    0.044203
# 7                    state_New South Wales    0.028118
# 16                           i9_health_Yes    0.019959
# 14                             gender_Male    0.017508
# 25                 i11_health_Very willing    0.017260
# 30              WCRex2_A lot of confidence    0.014763
# 18  employment_status_Part time employment    0.014633
# 27                    WCRex1_Somewhat well    0.014255
# 15                      i9_health_Not sure    0.013421
# ## After mandate - Protective behaviour
# ### Best hyperparameters
#    model__min_samples_split  model__min_samples_leaf  model__max_features  \
# 0                        10                        2                  0.3
#
#   model__max_depth  model__bootstrap
# 0             None              True
# ### Top search results
#     rank_test_score  mean_test_score  std_test_score param_model__max_depth  \
# 14                1         0.843554        0.006698                   None
# 23                2         0.840756        0.006395                     20
# 5                 3         0.840607        0.006562                   None
# 15                4         0.840436        0.005902                     12
# 31                5         0.840289        0.006694                     12
# 32                6         0.840056        0.006866                     15
# 33                7         0.839941        0.005940                     12
# 24                8         0.839817        0.006622                     20
# 9                 8         0.839817        0.006622                     20
# 37               10         0.839669        0.006304                     12
#
#     param_model__min_samples_split  param_model__min_samples_leaf  \
# 14                              10                              2
# 23                               5                              2
# 5                               20                              5
# 15                               2                              2
# 31                              10                              5
# 32                               5                             10
# 33                               5                              2
# 24                               2                             10
# 9                               20                             10
# 37                              10                              1
#
#    param_model__max_features  param_model__bootstrap
# 14                       0.3                    True
# 23                      sqrt                    True
# 5                        0.5                    True
# 15                       0.5                    True
# 31                       0.5                    True
# 32                       0.5                    True
# 33                       0.3                    True
# 24                       0.5                    True
# 9                        0.5                    True
# 37                       0.3                    True
# ### Test metrics
#            model              task                                 label  \
# 0  random_forest  after_protective  After mandate - Protective behaviour
#
#    best_cv_auc  precision  recall  roc_auc  accuracy      f1
# 0       0.8436     0.8604  0.8481   0.8415    0.7904  0.8542
# ### Top feature importance
#                                    feature  importance
# 0                                i2_health    0.132819
# 6                              week_number    0.132380
# 4                                     r1_1    0.087400
# 1                                      age    0.082775
# 25                 i11_health_Very willing    0.046369
# 3                           cantril_ladder    0.043984
# 13                 state_Western Australia    0.043063
# 5                                     r1_2    0.042127
# 2                           household_size    0.034793
# 9                         state_Queensland    0.028068
# 7                    state_New South Wales    0.022929
# 12                          state_Victoria    0.022829
# 16                           i9_health_Yes    0.021740
# 14                             gender_Male    0.013231
# 18  employment_status_Part time employment    0.011479
# ## Overall summary
#            model               task                                  label  \
# 0  random_forest        before_mask             Before mandate - Face mask
# 1  random_forest         after_mask              After mandate - Face mask
# 2  random_forest  before_protective  Before mandate - Protective behaviour
# 3  random_forest   after_protective   After mandate - Protective behaviour
#
#    best_cv_auc  precision  recall  roc_auc  accuracy      f1
# 0       0.8542     0.5968  0.6192   0.8407    0.7936  0.6078
# 1       0.8896     0.8850  0.9053   0.8895    0.8500  0.8950
# 2       0.7791     0.7260  0.7554   0.7963    0.7196  0.7404
# 3       0.8436     0.8604  0.8481   0.8415    0.7904  0.8542
