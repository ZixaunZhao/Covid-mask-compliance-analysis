# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from IPython.display import display, Markdown
from imblearn.over_sampling import RandomOverSampler
from imblearn.pipeline import Pipeline
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import StratifiedKFold, RandomizedSearchCV
from sklearn.metrics import (
    precision_score,
    recall_score,
    roc_auc_score,
    accuracy_score,
    f1_score,
    confusion_matrix,
    roc_curve,
)

DATA_DIR = Path("../data/paper_final_splits")

RANDOM_STATE = 20240627
N_SPLITS = 5
N_ITER_SEARCH = 40
TOP_N_FEATURES = 15

TASKS = {
    "before_mask": "Before mandate - Face mask",
    "after_mask": "After mandate - Face mask",
    "before_protective": "Before mandate - Protective behaviour",
    "after_protective": "After mandate - Protective behaviour",
}

METRICS = ["precision", "recall", "roc_auc", "accuracy", "f1"]


def load_task(task):
    X_train = pd.read_csv(DATA_DIR / f"X_train_{task}.csv")
    X_test = pd.read_csv(DATA_DIR / f"X_test_{task}.csv")
    y_train = pd.read_csv(DATA_DIR / f"y_train_{task}.csv").iloc[:, 0].astype(int)
    y_test = pd.read_csv(DATA_DIR / f"y_test_{task}.csv").iloc[:, 0].astype(int)
    return X_train, X_test, y_train, y_test


def get_metrics(y_true, y_pred, y_prob):
    return {
        "precision": precision_score(y_true, y_pred, zero_division=0),
        "recall": recall_score(y_true, y_pred, zero_division=0),
        "roc_auc": roc_auc_score(y_true, y_prob),
        "accuracy": accuracy_score(y_true, y_pred),
        "f1": f1_score(y_true, y_pred, zero_division=0),
    }


def build_search():
    pipe = Pipeline(steps=[
        ("ros", RandomOverSampler(random_state=RANDOM_STATE)),
        ("model", DecisionTreeClassifier(random_state=RANDOM_STATE))
    ])

    param_distributions = {
        "model__criterion": ["gini", "entropy"],
        "model__max_depth": [3, 5, 8, 10, 12, 15, 20, None],
        "model__min_samples_split": [2, 5, 10, 20, 30, 50],
        "model__min_samples_leaf": [1, 2, 5, 10, 20],
        "model__min_impurity_decrease": [0.0, 0.0001, 0.001, 0.005, 0.01],
    }

    cv = StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=RANDOM_STATE)

    search = RandomizedSearchCV(
        estimator=pipe,
        param_distributions=param_distributions,
        n_iter=N_ITER_SEARCH,
        scoring="roc_auc",
        cv=cv,
        random_state=RANDOM_STATE,
        n_jobs=1,
        refit=True,
        verbose=0,
        return_train_score=False,
    )
    return search


def plot_confusion_matrix(cm, title):
    fig, ax = plt.subplots(figsize=(4, 4))
    ax.imshow(cm)
    ax.set_title(title)
    ax.set_xlabel("Predicted label")
    ax.set_ylabel("True label")
    ax.set_xticks([0, 1])
    ax.set_yticks([0, 1])

    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, str(cm[i, j]), ha="center", va="center")

    plt.show()


def plot_roc_curve(y_true, y_prob, title):
    fpr, tpr, _ = roc_curve(y_true, y_prob)
    auc_value = roc_auc_score(y_true, y_prob)

    plt.figure(figsize=(5, 4))
    plt.plot(fpr, tpr, label=f"AUC = {auc_value:.4f}")
    plt.plot([0, 1], [0, 1], linestyle="--")
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title(title)
    plt.legend()
    plt.show()


def plot_top_importance(importance_df, title, top_n=15):
    top_df = importance_df.head(top_n).sort_values("importance", ascending=True)

    plt.figure(figsize=(8, max(5, top_n * 0.35)))
    plt.barh(top_df["feature"], top_df["importance"])
    plt.xlabel("Feature importance")
    plt.title(title)
    plt.show()


all_summary = []
results = {}

for task, label in TASKS.items():
    X_train, X_test, y_train, y_test = load_task(task)

    search = build_search()
    search.fit(X_train, y_train)

    best_model = search.best_estimator_
    best_params = search.best_params_
    best_cv_auc = search.best_score_

    cv_results_df = pd.DataFrame(search.cv_results_).sort_values("rank_test_score")
    display(Markdown(f"## {label}"))
    display(Markdown("### Best hyperparameters"))
    display(pd.DataFrame([best_params]))

    display(Markdown("### Top search results"))
    show_cols = [
        "rank_test_score",
        "mean_test_score",
        "std_test_score",
        "param_model__criterion",
        "param_model__max_depth",
        "param_model__min_samples_split",
        "param_model__min_samples_leaf",
        "param_model__min_impurity_decrease",
    ]
    display(cv_results_df[show_cols].head(10).round(6))

    y_test_pred = best_model.predict(X_test)
    y_test_prob = best_model.predict_proba(X_test)[:, 1]

    test_metrics = get_metrics(y_test, y_test_pred, y_test_prob)
    test_df = pd.DataFrame([{
        "model": "classification_tree",
        "task": task,
        "label": label,
        "best_cv_auc": best_cv_auc,
        **test_metrics
    }])

    display(Markdown("### Test metrics"))
    display(test_df.round(4))

    fitted_model = best_model.named_steps["model"]
    importance_df = pd.DataFrame({
        "feature": X_train.columns,
        "importance": fitted_model.feature_importances_
    }).sort_values("importance", ascending=False)

    display(Markdown("### Top feature importance"))
    display(importance_df.head(TOP_N_FEATURES).round(6))

    plot_top_importance(
        importance_df,
        title=f"Classification Tree - Top feature importance - {label}",
        top_n=TOP_N_FEATURES
    )

    plot_confusion_matrix(
        confusion_matrix(y_test, y_test_pred),
        title=f"Classification Tree - Confusion matrix - {label}"
    )

    plot_roc_curve(
        y_test,
        y_test_prob,
        title=f"Classification Tree - ROC curve - {label}"
    )

    results[task] = {
        "best_params": best_params,
        "best_cv_auc": best_cv_auc,
        "test_df": test_df,
        "importance_df": importance_df,
    }

    all_summary.append({
        "model": "classification_tree",
        "task": task,
        "label": label,
        "best_cv_auc": best_cv_auc,
        **test_metrics
    })

display(Markdown("## Overall summary"))
display(pd.DataFrame(all_summary).round(4))
# Out:
# ## Before mandate - Face mask
# ### Best hyperparameters
#    model__min_samples_split  model__min_samples_leaf  \
# 0                        50                        2
#
#    model__min_impurity_decrease  model__max_depth model__criterion
# 0                         0.001                15             gini
# ### Top search results
#     rank_test_score  mean_test_score  std_test_score param_model__criterion  \
# 30                1         0.816136        0.010939                   gini
# 31                1         0.816136        0.010939                   gini
# 18                1         0.816136        0.010939                   gini
# 25                4         0.812941        0.008961                entropy
# 13                5         0.807786        0.013274                entropy
# 21                6         0.807071        0.013146                entropy
# 36                7         0.806746        0.014025                entropy
# 0                 8         0.802518        0.008823                entropy
# 29                9         0.800659        0.010619                entropy
# 23                9         0.800659        0.010619                entropy
#
#    param_model__max_depth  param_model__min_samples_split  \
# 30                     20                              30
# 31                     10                               2
# 18                     15                              50
# 25                     20                              10
# 13                      5                              30
# 21                      5                              50
# 36                      5                              20
# 0                       8                              10
# 29                   None                              10
# 23                     12                               5
#
#     param_model__min_samples_leaf  param_model__min_impurity_decrease
# 30                              5                              0.0010
# 31                             20                              0.0010
# 18                              2                              0.0010
# 25                              2                              0.0010
# 13                             20                              0.0010
# 21                             10                              0.0001
# 36                             20                              0.0001
# 0                               1                              0.0001
# 29                              5                              0.0050
# 23                             20                              0.0050
# ### Test metrics
#                  model         task                       label  best_cv_auc  \
# 0  classification_tree  before_mask  Before mandate - Face mask       0.8161
#
#    precision  recall  roc_auc  accuracy      f1
# 0     0.4876  0.7137   0.8005    0.7324  0.5794
# ### Top feature importance
#                               feature  importance
# 6   protective_behaviour_nomask_scale    0.476137
# 8               state_New South Wales    0.242052
# 1                                 age    0.094205
# 7                         week_number    0.071935
# 4                                r1_1    0.052079
# 3                      cantril_ladder    0.017586
# 57               d1_comorbidities_Yes    0.016144
# 5                                r1_2    0.012399
# 17                      i9_health_Yes    0.009431
# 51            PHQ4_4_Nearly every day    0.008032
# 9            state_Northern Territory    0.000000
# 10                   state_Queensland    0.000000
# 12                     state_Tasmania    0.000000
# 11              state_South Australia    0.000000
# 13                     state_Victoria    0.000000
# ## After mandate - Face mask
# ### Best hyperparameters
#    model__min_samples_split  model__min_samples_leaf  \
# 0                        10                        2
#
#    model__min_impurity_decrease  model__max_depth model__criterion
# 0                         0.001                20          entropy
# ### Top search results
#     rank_test_score  mean_test_score  std_test_score param_model__criterion  \
# 25                1         0.860245        0.004746                entropy
# 0                 2         0.854597        0.003424                entropy
# 18                3         0.853897        0.002564                   gini
# 31                3         0.853897        0.002564                   gini
# 30                3         0.853897        0.002564                   gini
# 14                6         0.852137        0.002756                   gini
# 32                7         0.850541        0.003006                   gini
# 13                8         0.847034        0.003386                entropy
# 36                9         0.846564        0.003878                entropy
# 21               10         0.846464        0.003565                entropy
#
#    param_model__max_depth  param_model__min_samples_split  \
# 25                     20                              10
# 0                       8                              10
# 18                     15                              50
# 31                     10                               2
# 30                     20                              30
# 14                   None                              10
# 32                     10                              50
# 13                      5                              30
# 36                      5                              20
# 21                      5                              50
#
#     param_model__min_samples_leaf  param_model__min_impurity_decrease
# 25                              2                              0.0010
# 0                               1                              0.0001
# 18                              2                              0.0010
# 31                             20                              0.0010
# 30                              5                              0.0010
# 14                             20                              0.0001
# 32                              2                              0.0001
# 13                             20                              0.0010
# 36                             20                              0.0001
# 21                             10                              0.0001
# ### Test metrics
#                  model        task                      label  best_cv_auc  \
# 0  classification_tree  after_mask  After mandate - Face mask       0.8602
#
#    precision  recall  roc_auc  accuracy      f1
# 0     0.8827  0.8626   0.8546     0.822  0.8726
# ### Top feature importance
#                               feature  importance
# 6   protective_behaviour_nomask_scale    0.294680
# 7                         week_number    0.283107
# 10                   state_Queensland    0.155610
# 14            state_Western Australia    0.146380
# 1                                 age    0.028470
# 26            i11_health_Very willing    0.023450
# 12                     state_Tasmania    0.018300
# 5                                r1_2    0.014385
# 4                                r1_1    0.009068
# 30                   WCRex1_Very well    0.008250
# 17                      i9_health_Yes    0.005417
# 2                      household_size    0.003688
# 15                        gender_Male    0.003647
# 0                           i2_health    0.002811
# 27              WCRex1_Somewhat badly    0.002739
# ## Before mandate - Protective behaviour
# ### Best hyperparameters
#    model__min_samples_split  model__min_samples_leaf  \
# 0                        10                        2
#
#    model__min_impurity_decrease  model__max_depth model__criterion
# 0                         0.001                20          entropy
# ### Top search results
#     rank_test_score  mean_test_score  std_test_score param_model__criterion  \
# 25                1         0.730305        0.005595                entropy
# 21                2         0.728311        0.007533                entropy
# 36                3         0.728151        0.008590                entropy
# 13                4         0.728040        0.006478                entropy
# 18                5         0.724960        0.008386                   gini
# 30                5         0.724960        0.008386                   gini
# 31                5         0.724960        0.008386                   gini
# 0                 8         0.721629        0.007687                entropy
# 14                9         0.710488        0.006595                   gini
# 27               10         0.710066        0.007462                   gini
#
#    param_model__max_depth  param_model__min_samples_split  \
# 25                     20                              10
# 21                      5                              50
# 36                      5                              20
# 13                      5                              30
# 18                     15                              50
# 30                     20                              30
# 31                     10                               2
# 0                       8                              10
# 14                   None                              10
# 27                      3                              10
#
#     param_model__min_samples_leaf  param_model__min_impurity_decrease
# 25                              2                              0.0010
# 21                             10                              0.0001
# 36                             20                              0.0001
# 13                             20                              0.0010
# 18                              2                              0.0010
# 30                              5                              0.0010
# 31                             20                              0.0010
# 0                               1                              0.0001
# 14                             20                              0.0001
# 27                             20                              0.0010
# ### Test metrics
#                  model               task  \
# 0  classification_tree  before_protective
#
#                                    label  best_cv_auc  precision  recall  \
# 0  Before mandate - Protective behaviour       0.7303     0.7127   0.682
#
#    roc_auc  accuracy     f1
# 0   0.7435    0.6862  0.697
# ### Top feature importance
#                      feature  importance
# 0                  i2_health    0.419557
# 4                       r1_1    0.304322
# 7      state_New South Wales    0.105310
# 16             i9_health_Yes    0.064035
# 6                week_number    0.056758
# 12            state_Victoria    0.025710
# 5                       r1_2    0.009388
# 2             household_size    0.007498
# 15        i9_health_Not sure    0.007422
# 8   state_Northern Territory    0.000000
# 3             cantril_ladder    0.000000
# 1                        age    0.000000
# 9           state_Queensland    0.000000
# 11            state_Tasmania    0.000000
# 10     state_South Australia    0.000000
# ## After mandate - Protective behaviour
# ### Best hyperparameters
#    model__min_samples_split  model__min_samples_leaf  \
# 0                        10                        2
#
#    model__min_impurity_decrease  model__max_depth model__criterion
# 0                         0.001                20          entropy
# ### Top search results
#     rank_test_score  mean_test_score  std_test_score param_model__criterion  \
# 25                1         0.795590        0.007588                entropy
# 0                 2         0.790032        0.007651                entropy
# 32                3         0.786506        0.008590                   gini
# 14                4         0.784433        0.008574                   gini
# 30                5         0.784228        0.005824                   gini
# 31                5         0.784228        0.005824                   gini
# 18                5         0.784228        0.005824                   gini
# 36                8         0.775068        0.008604                entropy
# 21                9         0.774574        0.008527                entropy
# 13               10         0.774417        0.008812                entropy
#
#    param_model__max_depth  param_model__min_samples_split  \
# 25                     20                              10
# 0                       8                              10
# 32                     10                              50
# 14                   None                              10
# 30                     20                              30
# 31                     10                               2
# 18                     15                              50
# 36                      5                              20
# 21                      5                              50
# 13                      5                              30
#
#     param_model__min_samples_leaf  param_model__min_impurity_decrease
# 25                              2                              0.0010
# 0                               1                              0.0001
# 32                              2                              0.0001
# 14                             20                              0.0001
# 30                              5                              0.0010
# 31                             20                              0.0010
# 18                              2                              0.0010
# 36                             20                              0.0001
# 21                             10                              0.0001
# 13                             20                              0.0010
# ### Test metrics
#                  model              task  \
# 0  classification_tree  after_protective
#
#                                   label  best_cv_auc  precision  recall  \
# 0  After mandate - Protective behaviour       0.7956     0.8713  0.7478
#
#    roc_auc  accuracy      f1
# 0      0.8    0.7374  0.8048
# ### Top feature importance
#                         feature  importance
# 0                     i2_health    0.224338
# 6                   week_number    0.178702
# 25      i11_health_Very willing    0.144463
# 4                          r1_1    0.142593
# 9              state_Queensland    0.139099
# 13      state_Western Australia    0.127812
# 23  i11_health_Somewhat willing    0.016521
# 16                i9_health_Yes    0.012459
# 1                           age    0.007142
# 10        state_South Australia    0.006870
# 8      state_Northern Territory    0.000000
# 5                          r1_2    0.000000
# 7         state_New South Wales    0.000000
# 2                household_size    0.000000
# 12               state_Victoria    0.000000
# ## Overall summary
#                  model               task  \
# 0  classification_tree        before_mask
# 1  classification_tree         after_mask
# 2  classification_tree  before_protective
# 3  classification_tree   after_protective
#
#                                    label  best_cv_auc  precision  recall  \
# 0             Before mandate - Face mask       0.8161     0.4876  0.7137
# 1              After mandate - Face mask       0.8602     0.8827  0.8626
# 2  Before mandate - Protective behaviour       0.7303     0.7127  0.6820
# 3   After mandate - Protective behaviour       0.7956     0.8713  0.7478
#
#    roc_auc  accuracy      f1
# 0   0.8005    0.7324  0.5794
# 1   0.8546    0.8220  0.8726
# 2   0.7435    0.6862  0.6970
# 3   0.8000    0.7374  0.8048
